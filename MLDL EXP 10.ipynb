# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# Load dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Flatten images
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# Add noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(size=x_test.shape)

# Define autoencoder
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train model
autoencoder.fit(x_train_noisy, x_train,
                epochs=10,
                batch_size=256,
                validation_data=(x_test_noisy, x_test))

# Predict
decoded_imgs = autoencoder.predict(x_test_noisy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0550 - val_loss: 0.0303
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0255 - val_loss: 0.0215
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0199 - val_loss: 0.0184
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0177 - val_loss: 0.0169
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0164 - val_loss: 0.0161
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0157 - val_loss: 0.0156
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0149 - val_loss: 0.0150
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0146 - val_loss: 0.0148
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0144 - val_loss: 0.0146
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
